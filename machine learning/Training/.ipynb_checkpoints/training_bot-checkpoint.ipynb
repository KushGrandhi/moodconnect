# %%
import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
# things we need for Tensorflow
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import tensorflow as tf
import pandas as pd
import pickle
import random
import json

# %%
intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignore_words = ['?']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

# %%
training = []
output_empty = [0] * len(classes)
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training, dtype = object)
train_x = list(training[:,0])
train_y = list(training[:,1])

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.fit(np.array(train_x), np.array(train_y), epochs=100, batch_size=5, verbose=1)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 0s 888us/step - loss: 3.1893 - accuracy: 0.0000e+00
# Epoch 2/100
# 21/21 [==============================] - 0s 1ms/step - loss: 3.1013 - accuracy: 0.0594
# Epoch 3/100
# 21/21 [==============================] - 0s 1ms/step - loss: 3.0477 - accuracy: 0.1287
# Epoch 4/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.9871 - accuracy: 0.0891
# Epoch 5/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.9314 - accuracy: 0.1287
# Epoch 6/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.9281 - accuracy: 0.1188
# Epoch 7/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.7868 - accuracy: 0.2079
# Epoch 8/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.6790 - accuracy: 0.3366
# Epoch 9/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.5733 - accuracy: 0.2574
# Epoch 10/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.5222 - accuracy: 0.2277
# Epoch 11/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.5090 - accuracy: 0.2970
# Epoch 12/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.2395 - accuracy: 0.4356
# Epoch 13/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.1589 - accuracy: 0.4257
# Epoch 14/100
# 21/21 [==============================] - 0s 1ms/step - loss: 2.0152 - accuracy: 0.4851
# Epoch 15/100
# 21/21 [==============================] - 0s 1ms/step - loss: 1.8572 - accuracy: 0.5248
# Epoch 16/100
# 21/21 [==============================] - 0s 1ms/step - loss: 1.7467 - accuracy: 0.5248
# Epoch 17/100
# 21/21 [==============================] - 0s 1ms/step - loss: 1.7195 - accuracy: 0.5248
# Epoch 18/100
# 21/21 [==============================] - 0s 1ms/step - loss: 1.6008 - accuracy: 0.5347
# Epoch 19/100
# 21/21 [==============================] - 0s 1ms/step - loss: 1.3710 - accuracy: 0.5842
# Epoch 20/100
# 21/21 [==============================] - 0s 3ms/step - loss: 1.4292 - accuracy: 0.6139
# Epoch 21/100
# 21/21 [==============================] - 0s 3ms/step - loss: 1.4360 - accuracy: 0.5545
# Epoch 22/100
# 21/21 [==============================] - 0s 2ms/step - loss: 1.3541 - accuracy: 0.6238
# Epoch 23/100
# 21/21 [==============================] - 0s 4ms/step - loss: 1.3669 - accuracy: 0.6535
# Epoch 24/100
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0498 - accuracy: 0.7525
# Epoch 25/100
# 21/21 [==============================] - 0s 3ms/step - loss: 1.1194 - accuracy: 0.6436
# Epoch 26/100
# 21/21 [==============================] - 0s 4ms/step - loss: 1.0535 - accuracy: 0.7030
# Epoch 27/100
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0225 - accuracy: 0.7228
# Epoch 28/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8811 - accuracy: 0.7426
# Epoch 29/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.9416 - accuracy: 0.6931
# Epoch 30/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.8777 - accuracy: 0.7228
# Epoch 31/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6806 - accuracy: 0.8515
# Epoch 32/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.8137 - accuracy: 0.7228
# Epoch 33/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.8283 - accuracy: 0.7525
# Epoch 34/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7005 - accuracy: 0.7822
# Epoch 35/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7817 - accuracy: 0.7624
# Epoch 36/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6673 - accuracy: 0.7822
# Epoch 37/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6051 - accuracy: 0.8119
# Epoch 38/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7349 - accuracy: 0.7426
# Epoch 39/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6177 - accuracy: 0.8020
# Epoch 40/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5742 - accuracy: 0.8317
# Epoch 41/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5330 - accuracy: 0.8317
# Epoch 42/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4930 - accuracy: 0.8515
# Epoch 43/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.9109
# Epoch 44/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8812
# Epoch 45/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4216 - accuracy: 0.8614
# Epoch 46/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4881 - accuracy: 0.8713
# Epoch 47/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.9208
# Epoch 48/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.8812
# Epoch 49/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8614
# Epoch 50/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3910 - accuracy: 0.8911
# Epoch 51/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4143 - accuracy: 0.8812
# Epoch 52/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2777 - accuracy: 0.9307
# Epoch 53/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3696 - accuracy: 0.9109
# Epoch 54/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4129 - accuracy: 0.8416
# Epoch 55/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8812
# Epoch 56/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8614
# Epoch 57/100
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.8614
# Epoch 58/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.9208
# Epoch 59/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2521 - accuracy: 0.9307
# Epoch 60/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2372 - accuracy: 0.9208
# Epoch 61/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.9010
# Epoch 62/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2848 - accuracy: 0.9109
# Epoch 63/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3567 - accuracy: 0.9208
# Epoch 64/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2861 - accuracy: 0.9208
# Epoch 65/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2687 - accuracy: 0.9505
# Epoch 66/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2490 - accuracy: 0.9307
# Epoch 67/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1964 - accuracy: 0.9604
# Epoch 68/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9604
# Epoch 69/100
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.9307
# Epoch 70/100
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2943 - accuracy: 0.9307
# Epoch 71/100
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8911
# Epoch 72/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9703
# Epoch 73/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3509 - accuracy: 0.9208
# Epoch 74/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.9406
# Epoch 75/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2115 - accuracy: 0.9505
# Epoch 76/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9604
# Epoch 77/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3122 - accuracy: 0.9208
# Epoch 78/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1956 - accuracy: 0.9505
# Epoch 79/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2100 - accuracy: 0.9406
# Epoch 80/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1669 - accuracy: 0.9307
# Epoch 81/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.9307
# Epoch 82/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.9802
# Epoch 83/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1809 - accuracy: 0.9604
# Epoch 84/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2247 - accuracy: 0.9208
# Epoch 85/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.9505
# Epoch 86/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2076 - accuracy: 0.9406
# Epoch 87/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1265 - accuracy: 0.9604
# Epoch 88/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.9109
# Epoch 89/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9802
# Epoch 90/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1972 - accuracy: 0.9208
# Epoch 91/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1086 - accuracy: 0.9802
# Epoch 92/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.9802
# Epoch 93/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 0.9604
# Epoch 94/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1798 - accuracy: 0.9604
# Epoch 95/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1729 - accuracy: 0.9604
# Epoch 96/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1078 - accuracy: 0.9901
# Epoch 97/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1278 - accuracy: 0.9703
# Epoch 98/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1353 - accuracy: 0.9505
# Epoch 99/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1621 - accuracy: 0.9604
# Epoch 100/100
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1536 - accuracy: 0.9406

# %%
model.save('chatbot.h5',model)
pickle.dump( {'words':words, 'classes':classes, 'train_x':train_x, 'train_y':train_y}, open( "learning_chatbot.pkl", "wb" ) )
